# %% [markdown]
# # Examples
# Apply to Kerr examples Geminga, 3C 279,  Cygnus X-3

# %%
# %matplotlib inline
import main

# %% [markdown]
# ### Geminga
# Restrict range and print more info when loading gti, s/c, photons

# %%
self = main.Main('Geminga', mjd_range=(0,56000),verbose=2)
# Out:
# Selected position: (l,b)=(195.134,4.266), radius=5
# From MJD range [51910. 56000.] select years [0 5], months [ 0 44]
# Processing 5 GTI files ...  5 files, 29329 intervals with 1,509 days live time
# 	cut from 29,329 to 0 - 21165, or 21,165 entries after MJD range selection
# 	GTI MjD range: 54682.66-56000.02, good fraction 0.83
# Processing 5 S/C history (FT2) files
# 	Found 3,158,827 S/C entries:  919,270 remain after zenith and theta cuts
# 	cut from 919,270 to 0 - 919263, or 919,263 entries after MJD range selection
# Loading data from 44 months ............................................
# 	Selected 511637 photons within 5 deg of  (195.13,4.27)
# 	Dates: 2008-08-04 15:45 - 2012-03-14 00:33
# 	MJD  : 54682.7          - 56000.0
# Check to see if photons have valid exposure: find 511,636 photons within live time range
# 	exclude 4,628 not in an exposure bin--507,008 remain.

# %%
self.plot_normalized_rate()
# Out:
# Binning: 658 intervals of 2 days fronm 54682.7 to 56000.0
# exposure minimum factor, 0.3, removes 3/657 intervals

# %% [markdown]
# ### 3C 279
# Less setup output

# %%
tds = main.Main( '3C 279', interval=10, verbose=1)
# Out:
# Selected position: (l,b)=(305.104,57.062), radius=5
# Loading data from 127 months
# 	Selected 246775 photons within 5 deg of  (305.10,57.06)
# 	Dates: 2008-08-04 15:51 - 2018-08-01 19:25
# 	MJD  : 54682.7          - 58331.8

# %%
tds.plot_normalized_rate()
# Out:
# Binning: 364 intervals of 10 days fronm 54682.7 to 58331.8
# exposure minimum factor, 0.3, removes 4/363 intervals

# %% [markdown]
# ### Cygnus X-3
# Verbosity 0

# %%
tds = main.Main( 'Cygnus X-3', interval=10, verbose=0)

# %%
tds.plot_normalized_rate()
