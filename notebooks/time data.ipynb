# %% [markdown]
# # Load and plot time information for photons in a cone about a few blazars

# %%
# %matplotlib inline
# %reload_ext autoreload
# %autoreload
import timed_data
import importlib
importlib.reload(timed_data)
import os
os.environ['FERMI']='/nfs/farm/g/glast/g/catalog/pointlike/fermi'

# %%
position, name = (086.11106055, -38.18381855), '3C 454.3'
tds = timed_data.TimedData(position, name)
# Out:
# Opening 127 files, with 4.6 GB total
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . Selected 456388 photons

# %%
tds.df.head()
# Out:
#    band          time     delta
# 0     3  2.395604e+08  3.026941
# 1     0  2.395607e+08  2.012681
# 2     6  2.395607e+08  0.368780
# 3     6  2.395608e+08  0.463765
# 4     6  2.395610e+08  1.132868

# %%
tds.plot_time()

# %%
tds.plot_delta(squared=True)

# %%
position, name = (050.16392965516, +57.02266653441), 'B2 1520+31'
tds2 = timed_data.TimedData(position, name)

# %%
tds2.plot_delta(squared=True)

# %%
tds2.plot_time()

# %%
tds2.plot_time( xlim=(55000, 56200))

# %%
tds2.plot_time(xlim=(58000, None))

# %%
plot_time(tds2, xlim=(56500, 57000))

# %%
t0=55000; dts2.plot_time(xlim=(t0, t0+1000))
