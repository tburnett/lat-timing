# %%
# %matplotlib inline
import timed_data
os.environ['FERMI']='/nfs/farm/g/glast/g/catalog/pointlike/fermi'

# %%
position, name= (103.457,    44.7077), '504N-0110'
tds = timed_data.TimedData(position, name)
# Out:
# Opening 127 files, with 4.6 GB total
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . Selected 168908 photons

# %%
tds.plot_time()
tds.plot_delta(squared=True)

# %%
tds.plot_time(delta_t=10.)

# %%
position, name= (100,55), '(100,55)'
tdb = timed_data.TimedData(position, name)

tdb.plot_time(delta_t=10)
# Out:
# Opening 127 files, with 4.6 GB total
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . Selected 157440 photons
