# %% [markdown]
# # Process
# Especially Geminga and 3C

# %%
# %matplotlib inline
from importlib import reload

import main, exposure; 
list(map(reload, (main,exposure)));
import warnings
warnings.filterwarnings('error')

# %%
self = main.TimedData('Geminga', mjd_range=(0,56000),verbose=2)
# Out:
# Selected position: (l,b)=(195.134,4.266), radius=5
# Found 127 monthly photon data files, with 4.6 GB total
# Selected years [0 5], months [ 0 43]
# Loading data from 43 months ...........................................
# Selected 507440 photons within 5 deg of  (195.13,4.27)
# 	Date range: 2008-08-04 15:45     - 2012-03-02 20:03
# 	MJD:        54682.7              - 55988.8
# Processing GTI...
# Processed 5 GTI files wtth 29329 intervals with 130,387,659 s live time
# Loading FT2 files ['ft2_2008.fits', 'ft2_2009.fits', 'ft2_2010.fits', 'ft2_2011.fits', 'ft2_2012.fits']
# Finished loading FT2 files!
# Processing the FT2 file (calculating overlap with GTI)...
# Finished processing the FT2 file!
# Exposure time range: 239556978 to 378713732
# Selecting 659 intervals of 2 days

# %%
self.plot_normalized_rate()
# Out:
# Select 507,440 photons within live time range
# ... and exclude 4,596 photons not in GTI

# %% [markdown]
# ## Try a candidate pulsar

# %%
position, name= (103.457,    44.7077), '504N-0110'
tds = timed_data.TimedData( name, position) #,file_range=[0,17],)
# Out:
# Selected position: (l,b)=(103.457,44.708), radius=5
# Found 127 monthly files, with 4.6 GB total. Will read []
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# Selected 168908 photons within 5 deg of "504N-0110" at (103,45)
# 	Date range: 2008-08-04 16:24 to 2019-03-03 20:55

# %%
tds.get_exposure( day_interval=10)

tds.plot_normalized_rate()
# Out:
# Processing GTI...
# Processed 10 GTI files wtth 58079 intervals with 260,561,426 s live time
# Loading FT2 files ['ft2_2008.fits', 'ft2_2009.fits', 'ft2_2010.fits', 'ft2_2011.fits', 'ft2_2012.fits', 'ft2_2013.fits', 'ft2_2014.fits', 'ft2_2015.fits', 'ft2_2016.fits', 'ft2_2017.fits']
# Finished loading FT2 files!
# Processing the FT2 file (calculating overlap with GTI)...
# Finished processing the FT2 file!
# Exposure time range: 239556978 to 536518059
# Selecting 344 intervals of 10.0 days
# Select 148,754 photons within live time range
# ... and exclude 3,338 photons not in GTI
