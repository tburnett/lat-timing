# %% [markdown]
# # Process all data with 3C 279 or Geminga

# %%
# %matplotlib inline
from importlib import reload
import main
import light_curve
import warnings
warnings.filterwarnings('error')

# %%
agn = dict(source_name='3C 279', interval=5, mjd_range=None,
           weight_file='../data/3C279_weights.pkl')
geminga = dict(source_name='Geminga', mjd_range=None, interval=5,
               weight_file='../data/geminga_weights.pkl')

# %%
self = main.Main('Geminga',  interval=5, mjd_range=(0, 55500),  weight_file='../data/geminga_weights.pkl')
# Out:
# Selected position: (l,b)=(195.134,4.266), radius=5
# Loading data from 27 months
# 	Selected 329211 photons within 5 deg of  (195.13,4.27)
# 	Dates: 2008-08-04 15:45 - 2010-10-30 23:35
# 	MJD  : 54682.7          - 55500.0
# Adding weights from file /nfs/farm/g/glast/u/burnett/analysis/lat_timing/data/geminga_weights.pkl
# 	64 / 326403 photon pixels are outside weight region
# 	51786 weights set to NaN

# %%
bw=self.binned_weights()
# Out:
# Binning: 163 intervals of 5 days from 54682.66 to 55497.66

# %%
bw.test_plots();

# %%
reload(light_curve)
lc = light_curve.LightCurve(bw); 
lc.rate_plot()
# Out:
# Fits: 163 good, 0 failed

# %%
lc.fit(fix_beta=True)
# Out:
# Fits: 163 good, 0 failed

# %%
lc.rate_plot()
