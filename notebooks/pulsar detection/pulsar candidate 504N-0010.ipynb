# %% [markdown]
# # Study high-latitude pulsar candidate
#
# An objective of this development is to quickly generate light curves, and then variability measurements for candidate pulsars.
#
# This example source was selected from my [list of pulsar candidates](https://glast-ground.slac.stanford.edu/Decorator/exp/Fermi/Decorate/groups/catalog/pointlike/skymodels/P8_10years/uw9011/plots/pulsars/candidates.htm?skipDecoration)

# %%
# %matplotlib inline
import main
# !echo `date`
# Out:
# Tue Feb 18 11:25:07 PST 2020

# %%
src = dict(name = '504N-0110', l=6.923350, b=80.44889,
            weight_file='/nfs/farm/g/glast/g/catalog/pointlike/curr/uw9011/504N-0010_weights.pkl',
            image_dir='light_curves',
          )
# %time t=main.CombinedLightcurves(src, interval=5)
t.flux_plots();
# Out:
# Source "504N-0110" at: (l,b)=(6.923,80.449); ROI radius=5
# Raad /nfs/farm/g/glast/u/burnett/analysis/lat_timing/data/tstart.pkl with tstart values
# Loading data from 132 months from Arrow dataset /nfs/farm/g/glast/u/burnett/analysis/lat_timing/data/photon_dataset
#
# 	Selected 126072 photons within 5 deg of  (6.92,80.45)
# 	Dates: 2008-08-04 16:27 - 2019-08-03 00:29
# 	MJD  : 54682.7          - 58698.0
# Default binning: 2008 intervals of 2 days, in range (54683.0, 58698.0)
# Adding weights from file /nfs/farm/g/glast/g/catalog/pointlike/skymodels/P8_10years/uw9011/504N-0010_weights.pkl
# Found weights for 504N-0010 at (6.92, 80.45)
# 	2039 / 123988 photon pixels are outside weight region
# 	36654 weights set to NaN
# Creating weight model
# Loaded 1952 / 2008 cells with exposure > 0.3 for light curve analysis
# Fits using representation poisson: 1952 intervals
# Partitioned 1952 cells into 13 blocks, with prior 6.3
#  Used FitnessFunc class <class 'light_curve.LikelihoodFitness'>
# ...
