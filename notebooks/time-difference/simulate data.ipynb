# %% [markdown]
# # Use simulated data for AGN time-difference study

# %%
# %matplotlib inline
assert os.path.exists('../code/time_diffs.py'), 'Expect notebook folder to have this'
from time_diffs import TimeDiff # execute the python, which compiles the clsss TimeDiff

# %% [markdown]
# ### Default Parameters

# %%
TimeDiff?
# Out:
# Init signature: TimeDiff(dataset=None, **kwargs)
# Docstring:
# Simulation and analysis for AGN QPO search
#
# Init docstring:
# ...
# keyword arguments
# ...
# viewing_period 1000       number of days total
#
# ==========    SIMULATION
# noise_rate     0.4        noise photons/day
# agn_period     50.0       QPO period in days
# phase_width    0.1        spread in phase
# signal_count   25         average number of counts per cycle
#
# ==========    ANALYSIS
# window_size    400        window size in days
# max_freq       0.1        maximum frequency day**-1
#
# ==========    PROCESSING OPTIONS
# make_plots     True       generate plots for all steps
# binsize        10         Binsize (in days) for time plots
# ...
# File:           /nfs/farm/g/glast/u/burnett/analysis/agn_timing/code/time_diffs.py
# Type:           type
# Subclasses:

# %% [markdown]
# ### Create a TimeDiff object (which does the simulation) and run its analysis

# %%
tdo=TimeDiff()
tdo()
