# %% [markdown]
# # Use simulated data for AGN time-difference study

# %%
# %matplotlib inline
os.chdir('/nfs/farm/g/glast/u/burnett/analysis/agn')
# %run time_diffs

# %% [markdown]
# ### Default Parameters

# %%
TimeDiff?
# Out:
# Init signature: TimeDiff(self, dataset=None, **kwargs)
# Docstring:
# Simulation and analysis for AGN QPO search
#
# Init docstring:
# ...
# keyword arguments
# ...
# viewing_period 1000       number of days total
#
# ==========    SIMULATION
# noise_rate     0.2        noise photons/day
# agn_period     100.0      QPO period in days
# phase_width    0.05       spread in phase
# signal_count   20         average number of counts per cycle
#
# ==========    ANALYSIS
# window_size    400        window size in days
# max_freq       0.1        maximum frequency day**-1
#
# ==========    PROCESSING OPTIONS
# make_plots     True       generate plots for all steps
# binsize        10         Binsize (in days) for time plots
# ...
# Type:           type

# %% [markdown]
# ### Create a TimeDiff object (which does the simulation) and run its analysis

# %%
td=TimeDiff()
td()
