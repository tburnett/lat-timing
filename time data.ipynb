# %% [markdown]
# # develop time information for photons in cone

# %%
# %matplotlib inline
from uw.data import timed_data; reload(timed_data)
import glob, pickle, healpy
from astropy.io import fits
os.chdir(os.path.expandvars('$FERMI/data/P8_P305'))
plt.rc('font', size=12)

# %%
position, name = (086.11106055, -38.18381855), '3C 454.3'
tds = timed_data.TimedData(position, name)
# Out:
# Opening 127 files, with 4 GB total
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . Selected 456388 photons

# %%
    def plot_time(self, delta_max=2, delta_t=1, xlim=None):
        """
        """
        df = self.df

        t = timed_data.MJD(df.time)
        ta,tb=t[0],t[-1]
        Nbins = int((tb-ta)/float(delta_t))

        fig,ax= plt.subplots(figsize=(15,5))
        hkw = dict(bins = np.linspace(ta,tb,Nbins), histtype='step')
        ax.hist(t, label='E>100 MeV', **hkw)
        ax.hist(t[(df.delta<delta_max) & (df.band>0)], label='delta<{} deg'.format(delta_max), **hkw);
        ax.set(xlabel=r'$\mathsf{MJD}$', ylabel='counts per {:.0f} day'.format(delta_t))
        if xlim is not None: ax.set(xlim=xlim)
        ax.legend()
        ax.set_title('{} counts vs. time'.format(self.name))
    plot_time(tds)

# %%
tds.plot_delta(squared=True)

# %%
position, name = (050.16392965516, +57.02266653441), '7C 1520+3154'
tds2 = timed_data.TimedData(position, name)
# Out:
# Opening 127 files, with 4 GB total
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . Selected 177721 photons

# %%
tds2.plot_delta(squared=True)

# %%
plot_time(tds2)

# %%
plot_time(tds2, xlim=(55000, 56200))

# %%
plot_time(tds2, xlim=(58000, None))

# %%
plot_time(tds2, xlim=(56500, 57000))

# %%
t0=55000; plot_time(tds2, xlim=(t0, t0+1000))

# %%
len(tds2.df)
# Out:
# 177721
